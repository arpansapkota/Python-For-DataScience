# %% [markdown]
# Let's get started to python.
# Run following code in python.

# %%
print('I am excited to learn python')
# Out:
# I am excited to learn python

# %% [markdown]
# Python is interpreted language, which can save your considerable amount of time during development because no compilation and linking is required. Python interpreter can be used interactively.
#
# Python enables programs to be written compactly and readably. Programs written in Python are typically much shorter than equivalent C, C++, or Java programs, for several reasons:
#
# - the high-level data types allow you to express complex operations in a single statement;
# - statement grouping is done by indentation instead of beginning and ending brackets;
# - no variable or argument declarations are necessary.

# %% [markdown]
# ## Running python from command line
#
# <img src = 'https://media.geeksforgeeks.org/wp-content/uploads/20191211195520/Run-a-Python-Script-in-interactive-mode-GfG.png'>

# %% [markdown]
# ### Writing comments
# - Comments are the piece of text that the computer ignores but provides useful documentation for the programmers. Comments make the code more readable.
# There are two ways of writing comments :
# - Single line comment
#
# Example : # This is my first python program.
#
# - Multiline comment
#
# Example : " " " This is
#
# my first program" " "

# %% [markdown]
# ### Indentation
#
# - Spaces at the begining of the code line. Python uses indentation to represent block of code. You have to use same number of spaces in the same block of code.
#
#
# <img src = 'https://pythonexamples.org/wp-content/uploads/2020/08/python-indentation.png'>

# %% [markdown]
# Python also works as a calculator. In the interactive shell of python - python interpreter, you can compute.

# %%
#Sum of two numbers
282937+3938423
# Out:
# 4221360

# %%
# Arithematic Expression
(50 - 5*6) / 4
# Out:
# 5.0

# %%
#Division in Python
100/3
# Out:
# 33.333333333333336

# %%
#Getting Quotient
100//3
# Out:
# 33

# %%
#Getting remainder
100%3
# Out:
# 1

# %%
#Computing Square
24**2
# Out:
# 576

# %%
#Computing Cube
24**3
# Out:
# 13824

# %%
# Integer multiplied with float
1.5 * 8
# Out:
# 12.0

# %%
# Character multiplied with integer
'a' * 5
# Out:
# 'aaaaa'

# %% [markdown]
# Built in function **type** returns the type of any object.

# %%
type(7)
# Out:
# int

# %%
type(True)
# Out:
# bool

# %%
type(1)
# Out:
# int

# %%
type('a')
# Out:
# str

# %%
type(10.9)
# Out:
# float

# %%
import numpy as np

list_of_boolean = [True, False, True, True, False]

print(type(list_of_boolean))

np.sum(list_of_boolean)
# Out:
# <class 'list'>
# 3

# %% [markdown]
# __Exercise__
# 1. Practice different computation combination for numbers.

# %%
#!sudo apt-get install texlive-xetex texlive-fonts-recommended texlive-plain-generic

# %%
# !jupyter notebook nbconvert --to pdf/
