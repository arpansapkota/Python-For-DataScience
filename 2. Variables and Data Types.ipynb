# %% [markdown]
# # Variables
#
# Variables are named storage which are used to store value in memory. Value of variable keep on changing. That's why, they are variable.

# %%
#Defining Variable and printing the value
x = 10
print(x)
# Out:
# 10

# %%
what_is_your_name = 'Mani Pathak'
print(what_is_your_name)
# Out:
# Mani Pathak

# %%
man_is_immortal = True
print(man_is_immortal)
# Out:
# True

# %%
#Calculating Area of Rectangle
length = 10.5
breadth = 8
area = length * breadth

# %%
#Nothing result out from above codes. Because we didn't print anything.
print(area)
# Out:
# 84.0

# %% [markdown]
# **Exercise**
# 1. Write a python program to calculate Simple Interest.
# 2. Write a program to calculate area of circle.
# 3. Change value of rate and principal and calculate SI.
# 4. Calculate BMI (BMI = weight/height **2)

# %%
#Changing the value of variable
length = 11
area = length * breadth
print(area)
# Out:
# 88

# %%
#Assigning Multiple values to multiple variable
a, b, c = 3, 6, 8
print(a)
print(b)
print(c)

# %% [markdown]
# **Exercise**
# 1. Can we assign different type of multiple values to variables at once?
# a, b, c = 3, 1.5, 'Cheese!!!'

# %%
a, b, c = 3, 1.5, 'Cheese!!!'
print(a)
print(b)
print(c)
# Out:
# 3
# 1.5
# Cheese!!!

# %% [markdown]
# *Rules for Naming variables*
# 1. Variable names should have a combination of letters in lowercase (a to z) or uppercase (A to Z) or digits (0 to 9) or an underscore (_).
#
# ```
# python_class
# IPYTHON_CLASS
# pythonClass
# PythonClass
# ```
#
# 2. Always use a name of variable that is meaningful.
#
#
# ```
# length_of_rectangle = 100
# fiscal_year = 2019
# ```
#
# 3. Use capital letters for constants
#
#
# ```
# PI = 3.417
# SPEED_OF_LIGHT = ....
# ```
#
# 4. Never ever start variable with digit
# 5. Never use special symbols like !, #, $, @ etc. in variable names.

# %% [markdown]
# # Literals
#
# Literals are the raw data given in a variable or constants. Following are the different types of literals as follow:

# %% [markdown]
# 1. Numeric Literals

# %%
a = 0b1010 #Binary Literals
b = 100 #Decimal Literal 
c = 0o310 #Octal Literal
d = 0x12c #Hexadecimal Literal

#Float Literal
float_1 = 10.5 
float_2 = 1.5e2

#Complex Literal 
x = 3.14j

print(a, b, c, d)
print(float_1, float_2)
print(x, x.imag, x.real)
# Out:
# 10 100 200 300
# 10.5 150.0
# 3.14j 3.14 0.0

# %% [markdown]
# 2. String Literals

# %%
strings = "This is Python"
char = "C"
multiline_str = """This is a multiline string with more than one line code.

You don't trust me. See this example."""
unicode = u"\u00dcnic\u00f6de"
raw_str = r"raw \n string"

print(strings)
print(char)
print(multiline_str)
print(unicode)
print(raw_str)
# Out:
# This is Python
# C
# This is a multiline string with more than one line code.
#
# You don't trust me. See this example.
# Ünicöde
# raw \n string

# %% [markdown]
# 3. Boolean Literals

# %%
x = (1 == True)
y = (1 == False)
a = True + 4
b = False + 10

print("x is", x)
print("y is", y)
print("a:", a)
print("b:", b)
# Out:
# x is True
# y is False
# a: 5
# b: 10

# %% [markdown]
# 5. Special Literals
#
# Python has special literals i.e. None.

# %%
drink = "Available"
food = None

def menu(x):
    if x == drink:
        print(drink)
    else:
        print(food)

menu(drink)
menu(food)
# Out:
# Available
# None

# %% [markdown]
# # Data Types
#
# Python supports multiple data types. Since its a very high level language, supports many data types.
#
#
#
# ```
# Text Type     : 	str
# Numeric Types : 	int, float, complex
# Sequence Types: 	list, tuple, range
# Mapping Type  : 	dict
# Set Types     : 	set, frozenset
# Boolean Type  : 	bool
# Binary Types  : 	bytes, bytearray, memoryview
# ```
#
# Create variables of all built in data types.

# %%
#Numeric
counter = 18
print(counter)
print(type(counter))
# Out:
# 18
# <class 'int'>

# %%
#float
length = 100.5 
print(length)
print(type(length))
# Out:
# 100.5
# <class 'float'>

# %%
#complex
x = 1j
print(x)
print(type(x))
# Out:
# 1j
# <class 'complex'>

# %%
#string
website = 'http://newsummit.edu.np/'
print('Website: ', website)
print(type(website))
# Out:
# Website:  http://newsummit.edu.np/
# <class 'str'>

# %%
#List
fruits = ["apple", "banana", "cherry"]
print(fruits)
print(type(fruits))
# Out:
# ['apple', 'banana', 'cherry']
# <class 'list'>

# %%
# tuple
fruit_tuple = ("apple", "banana", "cherry")
print(fruit_tuple)
print(type(fruit_tuple))
# Out:
# ('apple', 'banana', 'cherry')
# <class 'tuple'>

# %%
#range
n = range(6)
print(n)
print(type(n))
# Out:
# range(0, 6)
# <class 'range'>

# %%
#Dictionary
student = {"name" : "Krish", "age" : 19}
print(student)
print(type(student))
# Out:
# {'name': 'Krish', 'age': 19}
# <class 'dict'>

# %%
#Set
a = {5,2,3,1,4}
print("a = ", a)
print(type(a))
# Out:
# a =  {1, 2, 3, 4, 5}
# <class 'set'>

# %%
#Frozenset
fruit_frozenset = frozenset({"apple", "banana", "cherry"})
print(fruit_frozenset)
print(type(fruit_frozenset))
# Out:
# frozenset({'apple', 'banana', 'cherry'})
# <class 'frozenset'>

# %%
# Boolean
x = True
y = False
print(x, y)
print(type(x), type(y))
# Out:
# True False
# <class 'bool'> <class 'bool'>

# %%
#Bytes
x = b"Hello"
print(x)
print(type(x))
# Out:
# b'Hello'
# <class 'bytes'>

# %%
#Byte Array
x = bytearray(10)
print(x)
print(type(x))
# Out:
# bytearray(b'\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00')
# <class 'bytearray'>

# %%
#Memory View
x = memoryview(bytes(5))
print(x)
print(type(x))
# Out:
# ...
# <class 'memoryview'>

# %% [markdown]
# # Operators in Python
#
# ```
# #Arithematic Operators
# +  Addition
# -  Subtraction
# *  Multiplication
# /  Division
# %  Modulus
# // Floor Division
# ** Exponent
#
# #Comparision Operator
# >  Greater than
# <  Less than
# == Equal to
# != Not Equal to
# >= Greater or Equal to
# <= Less or Equal to
#
# # Logical Operator
# and  True if both operands are true
# or   True if either of the operands is true
# not  True if operand is false
#
# # Assignment Operator
# =   x = 5
# +=  x += 5   =>  x = x + 5
# -=  x -= 5   =>  x = x - 5
# *=  x *= 5   =>  x = x * 5
# /=  x /= 5   =>  x = x / 5
# %=  x %= 5   =>	x = x % 5
# //= x //= 5  =>  x = x // 5
# **= x **= 5  =>  x = x ** 5
#
# #Identity Operator
# is
# is not
#
# Example:
#
# x = ["apple", "banana"]
# y = ["apple", "banana"]
# z = x
# print(x is z) #True
# print(x is y) #False
# print(x== y) #True
#
# #Membership Operator
# in
# not in
#
# Example :
# x = ["apple", "banana"]
# print("banana" in x) #True
#
#
# ```

# %% [markdown]
# # Comments
#  1. Single LIne Comment

# %%
# Caculating sum for two numbers
c = a + b

# %% [markdown]
#  2. Multi Line Comment

# %%
'''
This is a multiline comment.

Trust me it works. :)
'''
# Out:
# '\nThis is a multiline comment.\n\nTrust me it works. :)\n'

# %% [markdown]
# # Type Conversion
#
# The process of converting the value of one data type (integer, string, float, etc.) to another data type is called type conversion. Python has two types of type conversion.
#
# 1. **Implicit Type Conversion**: In Implicit type conversion, Python automatically converts one data type to another data type. This process doesn't need any user involvement.
#
# e.g.

# %%
num_int = 123
num_flo = 1.23

num_new = num_int + num_flo

print("datatype of num_int:",type(num_int))
print("datatype of num_flo:",type(num_flo))

print("Value of num_new:",num_new)
print("datatype of num_new:",type(num_new))
# Out:
# datatype of num_int: <class 'int'>
# datatype of num_flo: <class 'float'>
# Value of num_new: 124.23
# datatype of num_new: <class 'float'>

# %% [markdown]
# **Exercise** : Do you think below given expression will work?
#
# 'Welcome to Pascal' + 5
#
# Check and confirm in python interpreter.

# %% [markdown]
# 2. **Explicit Type Conversion**: In Explicit Type Conversion, users convert the data type of an object to required data type. We use the predefined functions like int(), float(), str(), etc to perform explicit type conversion.

# %%
age = 21
sweet = "Sweet "

print("Data type of num_int:",type(age))
print("Data type of num_str before Type Casting:",type(sweet))

age_str = str(age)
print("Data type of age after Type Casting:",type(age))

sweet_age = sweet + age_str

print("Sum of num_int and num_str:",sweet_age)
print("Data type of the sum:",type(sweet_age))
# Out:
# Data type of num_int: <class 'int'>
# Data type of num_str before Type Casting: <class 'str'>
# Data type of age after Type Casting: <class 'int'>
# Sum of num_int and num_str: Sweet 21
# Data type of the sum: <class 'str'>

# %% [markdown]
# Typecasting can be done by assigning the required data type function to the expression. Use the following functions to type cast
# 1. int()
# 2. str()
# 3. float()
#
# **Exercise**: Do the type conversion for following:
# 1. 4 to float
# 2. '4.5' to float
# 3. '1' to int
# 4. 'a' to int
# 5. 5.9 to int
